# %% [markdown]
# #***THEORITICAL QUESTION ***

# %% [markdown]
# #1 Can we use bagging for regression problems ?
#
# Yes we can use bagging for regression problem also
#
# from sklearn.ensemble import BaggingRegressor
# from sklearn.tree import DecisionTreeRegressor
# model = BaggingRegressor(
#     base_estimator=DecisionTreeRegressor(),
#     n_estimators=100,
#     random_state=42
# )
# #2 what is diff btw multiple model trainign and single model training?
#
# In multiple model training we can reduce error , make more stable predictions have higher accuracy whereas in sinle model traingin we use only 1 decission tree, have low accuracy , due to overfitting
#
# #3 what is concept of feature randomness in random forest ?
# at each split each tree look at a random subset of fatures  that make model less overfitting
#
# #4 What is OOB (Out-of-Bag) Score
# In random forest while selecting the random feature and datapoint from train data there are some data left over it . so there are numbers of feature and data selection occur in reperting way and in each time some datasets are left so the avg of calculation of that dataset is called OOBS
#
# #5 How can w measure important featur in a random forest model ?
#
# using .feature_importances_ in randomforestclassifier
#
# #6 Explain the working principle of a Bagging Classifier?
# baging mean bootstrap aggrregation
# it can train many model on a data subsets and combine their prediction so the final esult is more stable and accurate
#
# #7 How do you evaluate a Bagging Classifier’s performance?
# train test split , then cross validation then oob score and perform metrics
#
# #8. How does a Bagging Regressor work
# AS T IS BAGGING CLASSIFIER bagging regressor work but in place of discrete data there is a contineous output present and voting is done on taking the avaragee of the model
#
# #9 What is the main advantage of ensemble techniques
# It can reduce overfitting and predict more accurate result
#
# #10 what is main challenges of ensemble methods?
# computation cost as it have too many models complexity in tuning , requiered large dataset with smalll or noise data it perform poorly
#
# #11 what is key idea behind ensemble techique
# it combine multiple weak model to built aa stronger and mor accurate model
#
# #12 what is random forest clssifier ?
# MULTIPLE DECISION TREE MODEL ARE IN PARALLEL , THE ROW AND FEATURES ARE SELECTED RANDOMLY
#
# #13 What is main type of ensemble technique ?
# based on algorithm there aare 3 type of nsemble technique
# 1. parallel technique(bagging)
# 2. sequential technique(boosting)
# 3. parallel + sequential technique (stacking)
#
# #14. What is ensemble learning in ML ?
# Ensemble learning is a technique in ml where multiple model are trained and then combine to some the same problem
#
# #15 2 When should we avoid using ensemble methods
# we avoid it when we have small dataset , compuation source is limited , when we need real time prediction (bcz it take time ) and whn data is noisy
#
# #16. how does bagging help in redusing overfitting ?
# it take many random samples with replacement and train them sepreratly , so each model see diff subset of data to learn diff patterns ,so the rror of individual model cancel out and prediction bexome smoother less bias and more generalisable
#
# #17 Why is Random Forest better than a single Decision Tree?
# in single model overfiiting occur it use only 1 decision tree and have low accuracy thats why random forest is better than single decision tree as it ue multiple dicision tree
#
# #18 What is role of bootstrap sampling in bagging ?
# It mean select random sample with replacement from the trainign dataset
# each new dataset is called bootstrap sample
#
# #19  What are some real-world applications of ensemble techniques?
# in health diagnosis by taking advice from many doctor and with psicatrist nutritionist
#
# #20 What is the difference between Bagging and Boosting?
# In bagging (bootstap aggregation ) here all the model built parallely independent of each other whereas in bosting all the odel are built sequentialy and dependent on each other

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# #***PRACTICAL***

# %%
#21 Train a Bagging Classifier using Decision Trees on a sample dataset and print model accuracy
from sklearn.datasets import make_classification
from sklearn.model_selection  import train_test_split
a,b=make_classification(n_samples=1000,n_classes=2,n_features=20,random_state=42)
from sklearn.ensemble import BaggingClassifier
Bagging_Classifier=BaggingClassifier()
a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.2,random_state=42)
Bagging_Classifier.fit(a_train,b_train)
b_pred=Bagging_Classifier.predict(a_test)
from sklearn.metrics import accuracy_score
accuracy_score(b_test,b_pred)
# Out:
# 0.87

# %%
#22 Train a Bagging Regressor using Decision Trees and evaluate using Mean Squared Error (MSE)
from sklearn.datasets import make_regression
from sklearn.ensemble import BaggingRegressor
c,d=make_regression(n_samples=1000,n_features=10,random_state=42)
baggingregressor=BaggingRegressor(n_estimators=10,max_features=7)
c_train,c_test,d_train,d_test=train_test_split(c,d,test_size=0.2,random_state=42)
baggingregressor.fit(c_train,d_train)
d_pred=baggingregressor.predict(c_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(d_test,d_pred)
# Out:
# 4259.824539866533

# %%
#22 Train a Bagging Regressor using Decision Trees and evaluate using Mean Squared Error (MSE)
from sklearn.datasets import make_regression
from sklearn.ensemble import BaggingRegressor
c,d=make_regression(n_samples=1000,n_features=10,random_state=42)
baggingregressor=BaggingRegressor()
c_train,c_test,d_train,d_test=train_test_split(c,d,test_size=0.2,random_state=42)
baggingregressor.fit(c_train,d_train)
d_pred=baggingregressor.predict(c_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(d_test,d_pred)
# Out:
# 3745.6733416544007

# %%
#23 Train a random Forest Classifier on the Breast Cancer dataset and print feature importance scores
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
lbc=load_breast_cancer()
xc,yc=lbc.data,lbc.target
feature_name=lbc.feature_names
RFC=RandomForestClassifier()
xc_train,xc_test,yc_train,yc_test=train_test_split(xc,yc,test_size=0.2,random_state=42)
RFC.fit(xc_train,yc_train)
yc_pred=RFC.predict(xc_test)
print(f'the accuracy score is {accuracy_score(yc_test,yc_pred)}')
IMP_FEATURE=RFC.feature_importances_
F_I=pd.DataFrame({'feature': feature_name,'imp_score':IMP_FEATURE}).sort_values(by='imp_score',ascending=False)
F_I
# Out:
# the accuracy score is 0.956140350877193
#                     feature  imp_score
# 27     worst concave points   0.162583
# 7       mean concave points   0.150031
# 22          worst perimeter   0.128417
# 23               worst area   0.114011
# 6            mean concavity   0.061466
# 20             worst radius   0.059859
# 3                 mean area   0.047148
# 26          worst concavity   0.033625
# 2            mean perimeter   0.026076
# 10             radius error   0.025619
# 13               area error   0.024682
# 25        worst compactness   0.021341
# 21            worst texture   0.019734
# 12          perimeter error   0.018258
# 0               mean radius   0.014683
# 1              mean texture   0.012214
# 24         worst smoothness   0.011362
# 28           worst symmetry   0.009909
# 18           symmetry error   0.006361
# 19  fractal dimension error   0.006279
# 29  worst fractal dimension   0.005814
# 5          mean compactness   0.005515
# ...

# %%
#24 Train a Random Forest Regressor and compare its performance with a single Decision Tree
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error
x,y=make_regression(n_samples=500,n_features=10,random_state=42)
RFR=RandomForestRegressor()
x_tn,x_tt,y_tn,y_tt=train_test_split(x,y,test_size=0.2,random_state=42)
RFR.fit(x_tn,y_tn)
y_pred_rfr=RFR.predict(x_tt)
print(f'the root mean square error of Random forest regressor is {root_mean_squared_error(y_tt,y_pred_rfr)}')

from sklearn.tree import DecisionTreeRegressor
DTR=DecisionTreeRegressor()
DTR.fit(x_tn,y_tn)
Y_pred_dt=DTR.predict(x_tt)
print(f'the root mean sqaure error of decision tree is {root_mean_squared_error(y_tt,Y_pred_dt)}')
print('we know lower the RMSE better the performance so we can say that RFR prediction is better than single dt')
# Out:
# the root mean square error of Random forest regressor is 64.87179410160672
# the root mean sqaure error of decision tree is 99.19762207696364
# we know lower the RMSE better the performance so we can say that RFR prediction is better than single dt

# %%
#25 Compute the Out-of-Bag (OOB) Score for a Random Forest Classifier2
lbc=load_breast_cancer()
xc,yc=lbc.data,lbc.target
feature_name=lbc.feature_names
RFC=RandomForestClassifier(oob_score=True)
xc_train,xc_test,yc_train,yc_test=train_test_split(xc,yc,test_size=0.2,random_state=42)
RFC.fit(xc_train,yc_train)
yc_pred=RFC.predict(xc_test)
print(f'the accuracy score is {accuracy_score(yc_test,yc_pred)}')
print(f'the oobs score is {RFC.oob_score_}')
# Out:
# the accuracy score is 0.9649122807017544
# the oobs score is 0.9648351648351648

# %%
#26 Train bagging classifier using SVM as a base estimator and preint accuracy
a,b=make_classification(n_samples=1000,n_classes=2,n_features=20,random_state=42)
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
svc=SVC()
Bagging_Classifier=BaggingClassifier(estimator=svc)
a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.2,random_state=42)
Bagging_Classifier.fit(a_train,b_train)
b_pred=Bagging_Classifier.predict(a_test)
from sklearn.metrics import accuracy_score
accuracy_score(b_test,b_pred)
# Out:
# 0.85

# %%
#27 Train a Random Forest Classifier with different numbers of trees and compare accuracy
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
lbc=load_breast_cancer()
xc,yc=lbc.data,lbc.target
feature_name=lbc.feature_names
n_tree=[1,5,10,50,100]
xc_train,xc_test,yc_train,yc_test=train_test_split(xc,yc,test_size=0.2,random_state=42)
for i in n_tree:
  RFC=RandomForestClassifier(oob_score=True,n_estimators=i)
  RFC.fit(xc_train,yc_train)
  y_predrfc=RFC.predict(xc_test)
  acc=accuracy_score(yc_test,y_predrfc)
  print(f'number of tree {i} | Test accuracy is {acc:.4f} | oobs score {RFC.oob_score_:.4f}')
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:612: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:612: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:612: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# number of tree 1 | Test accuracy is 0.9035 | oobs score 0.5473
# number of tree 5 | Test accuracy is 0.9737 | oobs score 0.8462
# number of tree 10 | Test accuracy is 0.9649 | oobs score 0.9187
# number of tree 50 | Test accuracy is 0.9649 | oobs score 0.9626
# number of tree 100 | Test accuracy is 0.9649 | oobs score 0.9670

# %%
#28 Train a Bagging Classifier using Logistic Regression as a base estimator and print AUC score
a,b=make_classification(n_samples=500,n_features=10,n_informative=4,n_classes=3,random_state=42)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
Logistic_reg=LogisticRegression(max_iter=1000)
bc=BaggingClassifier(estimator=Logistic_reg)
a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.2,random_state=42)
bc.fit(a_train,b_train)
b_pred=bc.predict_proba(a_test)
roc_auc_score(b_test,b_pred,multi_class='ovr')
# Out:
# np.float64(0.87460333810338)

# %%
#29 Train a Random Forest Regressor and analyze feature importance scores2
x,y=make_regression(n_samples=500,n_features=10,random_state=42)
RFR=RandomForestRegressor()
x_tn,x_tt,y_tn,y_tt=train_test_split(x,y,test_size=0.2,random_state=42)
RFR.fit(x_tn,y_tn)
y_pred_rfr=RFR.predict(x_tt)
print(f'the root mean square error of Random forest regressor is {root_mean_squared_error(y_tt,y_pred_rfr)}')
fii=RFR.feature_importances_
feature_names = [f"Feature_{i}" for i in range(x.shape[1])]
feature_names
fi=pd.DataFrame({'feature':feature_names,'feature_imp':fii}).sort_values(by='feature_imp',ascending=False)
fi
# Out:
# the root mean square error of Random forest regressor is 63.1165853022052
#      feature  feature_imp
# 2  Feature_2     0.336088
# 5  Feature_5     0.201108
# 4  Feature_4     0.181531
# 0  Feature_0     0.068993
# 9  Feature_9     0.067445
# 3  Feature_3     0.040418
# 6  Feature_6     0.032213
# 8  Feature_8     0.030505
# 7  Feature_7     0.024802
# 1  Feature_1     0.016897

# %%
#30 Train an ensemble model using both Bagging and Random Forest and compare accurac
x,y=make_classification(n_samples=2000,n_features=30,n_classes=3,n_informative=4,random_state=42)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
bcc=BaggingClassifier()
rfcc=RandomForestClassifier()
bcc.fit(x_train,y_train)
rfcc.fit(x_train,y_train)
y_pred_bcc=bcc.predict(x_test)
y_pred_rfcc=rfcc.predict(x_test)
bccacc=accuracy_score(y_test,y_pred_bcc)
print(f'bagging classifier accuracy score is {bccacc}')
rfccacc=accuracy_score(y_test,y_pred_rfcc)
print(f'random forest accuracy score is {rfccacc}')
print(f'diff btw bcc and rfcc is {bccacc-rfccacc}')
# Out:
# bagging classifier accuracy score is 0.815
# random forest accuracy score is 0.8
# diff btw bcc and rfcc is 0.014999999999999902

# %%
'''#31 Train a Random Forest Classifier and tune hyperparameters using GridSearchCV
x,y=make_classification(n_samples=500,n_features=10,n_classes=2,random_state=42)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
params={'n_estimators' : [20,50,100,500], 'criterion': ["gini",'entropy'], 'max_depth': [1,10,50,100], 'min_samples_split':  [2,5,10]}
randomfc=RandomForestClassifier()
from sklearn.model_selection import GridSearchCV
tuning=GridSearchCV(randomfc,param_grid=params,verbose=2,cv=5 )
tuning.fit(x_train,y_train)'''
# Out:
# '#31 Train a Random Forest Classifier and tune hyperparameters using GridSearchCV\nx,y=make_classification(n_samples=500,n_features=10,n_classes=2,random_state=42)\nx_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)\nparams={\'n_estimators\' : [20,50,100,500], \'criterion\': ["gini",\'entropy\'], \'max_depth\': [1,10,50,100], \'min_samples_split\':  [2,5,10]}\nrandomfc=RandomForestClassifier()\nfrom sklearn.model_selection import GridSearchCV\ntuning=GridSearchCV(randomfc,param_grid=params,verbose=2,cv=5 )\ntuning.fit(x_train,y_train)'

# %%
y_pred=tuning.best_estimator_.predict(x_test)
print(accuracy_score(y_test,y_pred))
tuning.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1102896117.py in <cell line: 0>()
# ----> 1 y_pred=tuning.best_estimator_.predict(x_test)
#       2 print(accuracy_score(y_test,y_pred))
#       3 tuning.best_params_
#
# NameError: name 'tuning' is not defined

# %%
#32 Train a Bagging Regressor with different numbers of base estimators and compare performance=
c,d=make_regression(n_samples=1000,n_features=10,random_state=42)
c_train,c_test,d_train,d_test=train_test_split(c,d,test_size=0.2,random_state=42)
n_estimator_list=[1,5,10,50,100]
for n in n_estimator_list:
  model=BaggingRegressor(estimator=DecisionTreeRegressor(),n_estimators=n,random_state=42)
  model.fit(c_train,d_train)
  d_pred=model.predict(c_test )
  rmse=root_mean_squared_error(d_test,d_pred)
  print(f'{n} | root mean sq error is {rmse}')
# Out:
# 1 | root mean sq error is 92.65241757089294
# 5 | root mean sq error is 67.92184382065413
# 10 | root mean sq error is 60.485966946806485
# 50 | root mean sq error is 57.965392191056765
# 100 | root mean sq error is 56.375831208191514

# %%
#just to know everything well
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target
feature_names = iris.feature_names
class_names = iris.target_names

# Function to train and plot a tree
def show_tree(criterion, max_depth, min_samples_split, min_samples_leaf, max_features, title):
    clf = DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )
    clf.fit(X, y)

    plt.figure(figsize=(12,6))
    plot_tree(clf, feature_names=feature_names, class_names=class_names, filled=True, fontsize=8)
    plt.title(title, fontsize=14)
    plt.show()

# 1. criterion
show_tree("gini", max_depth=3, min_samples_split=2, min_samples_leaf=1, max_features=None,
          title="Criterion = Gini (default)")

show_tree("entropy", max_depth=3, min_samples_split=2, min_samples_leaf=1, max_features=None,
          title="Criterion = Entropy (information gain)")

# 2. max_depth
show_tree("gini", max_depth=2, min_samples_split=2, min_samples_leaf=1, max_features=None,
          title="Max Depth = 2 (shallow tree)")

show_tree("gini", max_depth=5, min_samples_split=2, min_samples_leaf=1, max_features=None,
          title="Max Depth = 5 (deeper tree)")

# 3. min_samples_split
show_tree("gini", max_depth=4, min_samples_split=10, min_samples_leaf=1, max_features=None,
          title="Min Samples Split = 10 (less branching)")

# 4. min_samples_leaf
show_tree("gini", max_depth=4, min_samples_split=2, min_samples_leaf=5, max_features=None,
          title="Min Samples Leaf = 5 (each leaf has ≥5 samples)")

# 5. max_features
show_tree("gini", max_depth=4, min_samples_split=2, min_samples_leaf=1, max_features=2,
          title="Max Features = 2 (randomly selects 2 features at each split)")

# %%
 #33 Train a Random Forest Classifier and analyze misclassified sample
 from sklearn.datasets import load_iris
 iriss=load_iris()
 x,y=iriss.data,iriss.target
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
 RFC=RandomForestClassifier()
 RFC.fit(x_train,y_train)
 y_pred=RFC.predict(x_test)
 from sklearn.metrics import classification_report
 print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.83      1.00      0.91        10
#            2       1.00      0.86      0.92        14
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.95      0.94        30
# weighted avg       0.94      0.93      0.93        30

# %%
#34 Train a Bagging Classifier and compare its performance with a single Decision Tree Classifier
x,y=make_classification(n_samples=500,n_features=20,n_classes=2,random_state=21)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
#for bagging
bgclf=BaggingClassifier()
bgclf.fit(x_train,y_train)
y_pred_bgclf=bgclf.predict(x_test)
#decision tree
from sklearn.tree import DecisionTreeClassifier
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
y_pred_dtc=DTC.predict(x_test)
print(f"the accuracy of baging classifier is {accuracy_score(y_test,y_pred_bgclf)}")
print(f"the accuracy of decision tree is {accuracy_score(y_test,y_pred_dtc)}")
# Out:
# the accuracy of baging classifier is 0.83
# the accuracy of decision tree is 0.81

# %%
#35 Train a Random Forest Classifier and visualize the confusion matrix=
randomforest=RandomForestClassifier()
randomforest.fit(x_train,y_train)
y_pred=randomforest.predict(x_test)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[48,  4],
#        [10, 38]])

# %%
#36 Train a Stacking Classifier using Decision Trees, SVM, and Logistic Regression, and compare accuracy
from sklearn.ensemble import VotingClassifier
decision_tree=DecisionTreeClassifier()
SVM=SVC()
L_rg=LogisticRegression()
vc=VotingClassifier(estimators=[('decision tree',decision_tree),('SVM',SVM),('LOGISTIC',L_rg)],voting='hard')
vc.fit(x_train,y_train)
y_pred = vc.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.86

# %%
#37 Train a Random Forest Classifier and print the top 5 most important features=
randomforest=RandomForestClassifier()
randomforest.fit(x_train,y_train)
y_pred=randomforest.predict(x_test)
feature_namee= [f"Feature_{i}" for i in range(x.shape[1])]
IMP_FEATURE=randomforest.feature_importances_
pd.DataFrame({'feature': feature_namee,'imp_score':IMP_FEATURE}).sort_values(by='imp_score',ascending=False).head()
# Out:
#        feature  imp_score
# 14  Feature_14   0.406194
# 12  Feature_12   0.172107
# 6    Feature_6   0.134421
# 17  Feature_17   0.041067
# 0    Feature_0   0.018512

# %%
#38 Train a Bagging Classifier and evaluate performance using Precision, Recall, and F1-score=
x,y=make_classification(n_samples=500,n_features=20,n_classes=2,random_state=2)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)
bgc=BaggingClassifier()
bgc.fit(x_train,y_train)
y_pred=bgc.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        68
#            1       0.92      0.79      0.85        82
#
#     accuracy                           0.85       150
#    macro avg       0.85      0.85      0.85       150
# weighted avg       0.86      0.85      0.85       150

# %%
#39 Train a Random Forest Classifier and analyze the effect of max_depth on accuracy=
max_depth=[2,5,10,20,50,100]
for i in max_depth:
  r=RandomForestClassifier(max_depth=i)
  r.fit(x_train,y_train)
  y_pred=r.predict(x_test)
  print(f'max_depth = {i} | accuracy = {accuracy_score(y_test,y_pred)}')
# Out:
# max_depth = 2 | accuracy = 0.86
# max_depth = 5 | accuracy = 0.8733333333333333
# max_depth = 10 | accuracy = 0.88
# max_depth = 20 | accuracy = 0.8733333333333333
# max_depth = 50 | accuracy = 0.8666666666666667
# max_depth = 100 | accuracy = 0.8666666666666667

# %%
#40 Train a Bagging Regressor using different base estimators (DecisionTree and KNeighbors) and compare  performance
x,y=make_regression(n_samples=500,n_features=20)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
br_dtc=BaggingRegressor(estimator=DecisionTreeRegressor())
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
br_k=BaggingRegressor(estimator=knn)
br_dtc.fit(x_train,y_train)
br_k.fit(x_train,y_train)
y_pred_brdtc=br_dtc.predict(x_test)
y_pred_br_k=br_k.predict(x_test)
print(f"rmse of brdtc is {root_mean_squared_error(y_test,y_pred_brdtc) } and rmse of Kneighbor is {root_mean_squared_error(y_test,y_pred_br_k)}")
# Out:
# rmse of brdtc is 73.17850015053054 and rmse of Kneighbor is 94.07698805275433

# %%
# Train a Random Forest Classifier and evaluate its performance using ROC-AUC Score=
x,y=make_classification(n_samples=500,n_features=20,n_classes=2,random_state=2)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)
rfcc=RandomForestClassifier()
rfcc.fit(x_train,y_train)
y_pred=rfcc.predict(x_test)
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred)
# Out:
# np.float64(0.8753586800573888)

# %%
# Train a Bagging Classifier and evaluate its performance using cross-validatio.
x,y=make_classification(n_samples=500,n_features=20,n_classes=2,random_state=2)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)
bgc=BaggingClassifier()
bgc.fit(x_train,y_train)
y_pred=bgc.predict(x_test)
from sklearn.model_selection import cross_val_score
cross_val_score(bgc,x_test,y_test,cv=5,scoring='accuracy')
# Out:
# array([0.8       , 0.9       , 0.83333333, 0.76666667, 0.8       ])

# %%
#45 Train a Bagging Regressor with different levels of bootstrap samples and compare performance.
x,y=make_regression(n_samples=500,n_features=20)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
bootstrap_samples = [0.5, 0.7, 1.0]
bootstrap_options = [True, False]     # with and without replacement

for bootstrap in bootstrap_options:
  for frac in bootstrap_samples:
        model = BaggingRegressor(
            estimator=DecisionTreeRegressor(),
            n_estimators=100,
            max_samples=frac,
            bootstrap=bootstrap,# controls bootstrap sample size
            random_state=42
        )
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        print(f"  max_samples={frac} | RMSE={rmse:.3f}")
# Out:
#   max_samples=0.5 | RMSE=63.433
#   max_samples=0.7 | RMSE=64.286
#   max_samples=1.0 | RMSE=62.699
#   max_samples=0.5 | RMSE=62.910
#   max_samples=0.7 | RMSE=62.127
#   max_samples=1.0 | RMSE=98.266
